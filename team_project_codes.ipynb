# %% [markdown]
# # 팀프로젝트

# %%
# !pip install scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# %%
import pandas as pd

train_df = pd.read_csv("./data/mushroom_train.csv")
test_df = pd.read_csv("./data/mushroom_test.csv")

# %%
train_df
# Out:
#       mushroom_id class cap-shape cap-surface cap-color bruises odor  \
# 0               0     p         x           s         n       t    p
# 1               1     e         x           s         y       t    a
# 2               2     e         b           s         w       t    l
# 3               3     p         x           y         w       t    p
# 4               4     e         x           s         g       f    n
# ...           ...   ...       ...         ...       ...     ...  ...
# 6495         6495     p         f           y         n       f    y
# 6496         6496     p         f           s         e       f    y
# 6497         6497     p         f           s         e       f    f
# 6498         6498     p         f           y         n       f    s
# 6499         6499     p         f           s         e       f    f
#
#      gill-attachment gill-spacing gill-size  ... stalk-surface-below-ring  \
# ...

# %%
test_df
# Out:
#       mushroom_id cap-shape cap-surface cap-color bruises odor  \
# 0            6500         f           s         n       f    f
# 1            6501         k           y         e       f    s
# 2            6502         f           y         e       f    f
# 3            6503         f           s         e       f    f
# 4            6504         f           y         e       f    y
# ...           ...       ...         ...       ...     ...  ...
# 1619         8119         k           s         n       f    n
# 1620         8120         x           s         n       f    n
# 1621         8121         f           s         n       f    n
# 1622         8122         k           y         n       f    y
# 1623         8123         x           s         n       f    n
#
#      gill-attachment gill-spacing gill-size gill-color  ...  \
# 0                  f            c         n          b  ...
# 1                  f            c         n          b  ...
# ...

# %%
df = pd.concat([train_df,test_df]).reset_index(drop=True)

# %%
df
# Out:
#       mushroom_id class cap-shape cap-surface cap-color bruises odor  \
# 0               0     p         x           s         n       t    p
# 1               1     e         x           s         y       t    a
# 2               2     e         b           s         w       t    l
# 3               3     p         x           y         w       t    p
# 4               4     e         x           s         g       f    n
# ...           ...   ...       ...         ...       ...     ...  ...
# 8119         8119   NaN         k           s         n       f    n
# 8120         8120   NaN         x           s         n       f    n
# 8121         8121   NaN         f           s         n       f    n
# 8122         8122   NaN         k           y         n       f    y
# 8123         8123   NaN         x           s         n       f    n
#
#      gill-attachment gill-spacing gill-size  ... stalk-surface-below-ring  \
# ...

# %%
df.shape
# Out:
# (8124, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   mushroom_id               8124 non-null   int64
#  1   class                     6500 non-null   object
#  2   cap-shape                 8124 non-null   object
#  3   cap-surface               8124 non-null   object
#  4   cap-color                 8124 non-null   object
#  5   bruises                   8124 non-null   object
#  6   odor                      8124 non-null   object
#  7   gill-attachment           8124 non-null   object
#  8   gill-spacing              8124 non-null   object
#  9   gill-size                 8124 non-null   object
#  10  gill-color                8124 non-null   object
#  11  stalk-shape               8124 non-null   object
#  12  stalk-root                8124 non-null   object
# ...

# %%
df.describe()
# Out:
#        mushroom_id
# count  8124.000000
# mean   4061.500000
# std    2345.341127
# min       0.000000
# 25%    2030.750000
# 50%    4061.500000
# 75%    6092.250000
# max    8123.000000

# %%
df.isnull().sum()
# Out:
# mushroom_id                    0
# class                       1624
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                     0
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# dtype: int64

# %%
df
# Out:
#       mushroom_id class cap-shape cap-surface cap-color bruises odor  \
# 0               0     p         x           s         n       t    p
# 1               1     e         x           s         y       t    a
# 2               2     e         b           s         w       t    l
# 3               3     p         x           y         w       t    p
# 4               4     e         x           s         g       f    n
# ...           ...   ...       ...         ...       ...     ...  ...
# 8119         8119   NaN         k           s         n       f    n
# 8120         8120   NaN         x           s         n       f    n
# 8121         8121   NaN         f           s         n       f    n
# 8122         8122   NaN         k           y         n       f    y
# 8123         8123   NaN         x           s         n       f    n
#
#      gill-attachment gill-spacing gill-size  ... stalk-surface-below-ring  \
# ...

# %%
df.drop(["ring-number","ring-type","gill-attachment","stalk-root"], axis=1)
# Out:
#       mushroom_id class cap-shape cap-surface cap-color bruises odor  \
# 0               0     p         x           s         n       t    p
# 1               1     e         x           s         y       t    a
# 2               2     e         b           s         w       t    l
# 3               3     p         x           y         w       t    p
# 4               4     e         x           s         g       f    n
# ...           ...   ...       ...         ...       ...     ...  ...
# 8119         8119   NaN         k           s         n       f    n
# 8120         8120   NaN         x           s         n       f    n
# 8121         8121   NaN         f           s         n       f    n
# 8122         8122   NaN         k           y         n       f    y
# 8123         8123   NaN         x           s         n       f    n
#
#      gill-spacing gill-size gill-color stalk-shape stalk-surface-above-ring  \
# ...

# %%
df
# Out:
#       mushroom_id class cap-shape cap-surface cap-color bruises odor  \
# 0               0     p         x           s         n       t    p
# 1               1     e         x           s         y       t    a
# 2               2     e         b           s         w       t    l
# 3               3     p         x           y         w       t    p
# 4               4     e         x           s         g       f    n
# ...           ...   ...       ...         ...       ...     ...  ...
# 8119         8119   NaN         k           s         n       f    n
# 8120         8120   NaN         x           s         n       f    n
# 8121         8121   NaN         f           s         n       f    n
# 8122         8122   NaN         k           y         n       f    y
# 8123         8123   NaN         x           s         n       f    n
#
#      gill-attachment gill-spacing gill-size  ... stalk-surface-below-ring  \
# ...

# %%
#파생변수의 생성

# %%
#Label Encodingg할것들(0,1로 표현): gill-size, stalk-shape, veil-type, ring-number,

# %%
#One Hot Encoding할 것들(순서 없음, dummy화): 
#gill-attachment, gill-spacing, gill-color, stalk-root, stalk-surface-above-ring, stalk-surface-above-ring, 
#stalk-color-above-ring, stalk-color-below-ring, veil-color, ring-type, spore-print-color, habitat

# %%
#population만 순서가 존재

# %%
# !pip install scikit-learn

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

# %%
df.isnull().sum()
# Out:
# mushroom_id                    0
# class                       1624
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                     0
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# dtype: int64

# %%
# import seaborn as sns
# from matplotlib import pyplot as plt

# cmap = sns.diverging_palette(240, 10, n=9, as_cmap=True)
# plt.figure(figsize=(10, 8))
# sns.heatmap(
#     df.corr(), 
#     annot=True, 
#     fmt=".2f", 
#     cmap=cmap, 
#     linewidths=.5, 
#     annot_kws={"size": 7}
# )
